# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1500)
pd.set_option('display.precision', 3)

# %% [markdown]
# ## Day of the Week Plot

# %%
#Bring in cleaned turnstile data

with open('turnstile_day_of_wk_df.pkl', 'rb') as read_file:
    turnstile_day_of_wk_df = pickle.load(read_file)
    
turnstile_day_of_wk_df.head(100)
# Out:
#          TURNSTILE          STATION       DATE  year  hour  day_of_week  \
# 2    R001|00-00-00  WHITEHALL S-FRY 2016-02-29  2016     8            0
# 3    R001|00-00-00  WHITEHALL S-FRY 2016-02-29  2016    12            0
# 4    R001|00-00-00  WHITEHALL S-FRY 2016-02-29  2016    16            0
# 5    R001|00-00-00  WHITEHALL S-FRY 2016-02-29  2016    20            0
# 8    R001|00-00-00  WHITEHALL S-FRY 2016-03-01  2016     8            1
# 9    R001|00-00-00  WHITEHALL S-FRY 2016-03-01  2016    12            1
# 10   R001|00-00-00  WHITEHALL S-FRY 2016-03-01  2016    16            1
# 11   R001|00-00-00  WHITEHALL S-FRY 2016-03-01  2016    20            1
# 14   R001|00-00-00  WHITEHALL S-FRY 2016-03-02  2016     8            2
# 15   R001|00-00-00  WHITEHALL S-FRY 2016-03-02  2016    12            2
# 16   R001|00-00-00  WHITEHALL S-FRY 2016-03-02  2016    16            2
# 17   R001|00-00-00  WHITEHALL S-FRY 2016-03-02  2016    20            2
# ...

# %%
# Generate day of the week dataframe.  Add up cumulative entries and exits 
# for the tech stations, and then find the mean for each day of the week.

tech_stations = ['TIMES SQ-42 ST','8 ST-NYU','ASTOR PL','14 ST-UNION SQ',    \
                 '34 ST-HUDSON YD','34 ST-PENN STA','28 ST','23 ST',    \
                 'SPRING ST','PRINCE ST','CORTLANDT ST','WTC-CORTLANDT',    \
                 'FULTON ST','PARK PLACE','18 ST','14 ST']

turnstile_date_df = cons_turnstile_df6.groupby(['STATION', 'DATE','day_of_week'])    \
.agg({'Cum. Entries & Exits':'sum'}).reset_index()

ts_tech_df = turnstile_date_df.loc[turnstile_date_df['STATION'].isin(tech_stations)]

ts_tech_day_of_wk_df = ts_tech_df.groupby(['day_of_week'])    \
.agg({'Cum. Entries & Exits':'mean'}).reset_index()

# %%
ts_tech_day_of_wk_df
# Out:
#    day_of_week  Cum. Entries & Exits
# 0            0             86847.440
# 1            1             89923.373
# 2            2             90781.557
# 3            3             92498.526
# 4            4             88433.465

# %%
#Plot the dataframe created above

sns.barplot(x = 'day_of_week',y='Cum. Entries & Exits',data=ts_tech_day_of_wk_df, palette = "pastel")    \
            .set(xlabel = 'Day of Week', ylabel = 'Avg. Daily Foot Traffic', xticklabels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], yticklabels = ['0', '20,000', '40,000', '60,000', '80,000'])
# Out:
# [[Text(0, 0, '0'),
#   Text(0, 0, '20,000'),
#   Text(0, 0, '40,000'),
#   Text(0, 0, '60,000'),
#   Text(0, 0, '80,000')],
#  Text(0, 0.5, 'Avg. Daily Foot Traffic'),
#  [Text(0, 0, 'Monday'),
#   Text(0, 0, 'Tuesday'),
#   Text(0, 0, 'Wednesday'),
#   Text(0, 0, 'Thursday'),
#   Text(0, 0, 'Friday')],
#  Text(0.5, 0, 'Day of Week')]

# %% [markdown]
# ## Median Household Income Plot

# %%
# Bring in median household income dataset

with open('income_df.pkl','rb') as read_file:
    income_df = pickle.load(read_file)
    
income_df.head(5)
# Out:
#        short_name                        long_name  \
# 0  hh_inc_med_adj  Median household income (2018$)
# 1  hh_inc_med_adj  Median household income (2018$)
# 2  hh_inc_med_adj  Median household income (2018$)
# 3  hh_inc_med_adj  Median household income (2018$)
# 4  hh_inc_med_adj  Median household income (2018$)
#
#                Sub-Borough Area       2000   2005       2006       2007  \
# 0       Williamsburg/Greenpoint  41741.847  37710  40056.728  49239.464
# 1  Brooklyn Heights/Fort Greene  63540.368  63290  68134.997  77225.749
# 2            Bedford Stuyvesant  35248.671  38140  34218.144  37807.410
# 3                      Bushwick  35557.870  31590  34533.073  38019.628
# 4   East New York/Starrett City  42360.245  38230  34799.646  39031.282
#
#         2008       2009       2010       2011       2012       2013  \
# 0  47871.101  45330.872  47576.798  51921.733  54490.297  55849.473
# 1  72165.267  76440.384  81561.523  68537.837  82053.949  81016.309
# ...

# %%
# Determine 10 sub-boroughs with highest median household income in 2017

income_sorted_df = income_df.sort_values('2017')
income_top10_df = income_sorted_df.tail(10)
income_top10_df
# Out:
#         short_name                        long_name  \
# 53  hh_inc_med_adj  Median household income (2018$)
# 50  hh_inc_med_adj  Median household income (2018$)
# 1   hh_inc_med_adj  Median household income (2018$)
# 54  hh_inc_med_adj  Median household income (2018$)
# 27  hh_inc_med_adj  Median household income (2018$)
# 17  hh_inc_med_adj  Median household income (2018$)
# 18  hh_inc_med_adj  Median household income (2018$)
# 19  hh_inc_med_adj  Median household income (2018$)
# 5   hh_inc_med_adj  Median household income (2018$)
# 25  hh_inc_med_adj  Median household income (2018$)
#
#                         Sub-Borough Area        2000    2005        2006  \
# 53                            Mid-Island   86467.464   73670   85601.154
# 50                        Queens Village   87673.340   83630   81885.240
# 1           Brooklyn Heights/Fort Greene   63540.368   63290   68134.997
# 54                           South Shore   97397.644   99460  101586.896
# ...

# %%
# Plot dataframe created above

income_2017 = list(income_top10_df['2017'])
clrs = ['blueviolet' if x == income_2017[9] or x == income_2017[4] else 'plum' for x in income_2017]
sns.barplot(x = '2017',y='Sub-Borough Area',data=income_top10_df, palette = clrs)    \
            .set(xlabel = 'Median Household Income (2017)', ylabel = 'Sub-Borough Area')
# Out:
# [Text(0, 0.5, 'Sub-Borough Area'),
#  Text(0.5, 0, 'Median Household Income (2017)')]

# %% [markdown]
# ## Education Level Plot

# %%
#Bring in bachelor degree dataset

with open('degree_df.pkl','rb') as read_file:
    degree_df = pickle.load(read_file)
    
degree_df.head(5)
# Out:
#           short_name                                          long_name  \
# 0  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 1  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 2  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 3  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 4  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
#
#              Sub-Borough Area   2000   2005   2006   2007   2008   2009  \
# 0                 East Harlem  0.142  0.257  0.220  0.218  0.237  0.257
# 1   Washington Heights/Inwood  0.190  0.270  0.256  0.296  0.288  0.325
# 2      Mott Haven/Hunts Point  0.048  0.063  0.080  0.081  0.083  0.080
# 3          Morrisania/Belmont  0.076  0.083  0.077  0.083  0.113  0.099
# 4  Highbridge/South Concourse  0.078  0.079  0.096  0.089  0.112  0.126
#
#     2010   2011   2012   2013   2014   2015   2016   2017
# ...

# %%
# Determine 10 sub-boroughs with highest % of >25 demographic with
# Bachelor's Degree in 2017

degree_sorted_df = degree_df.sort_values('2017')
degree_top10_df = degree_sorted_df.tail(10)
degree_top10_df
# Out:
#            short_name                                          long_name  \
# 38  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 12  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 43  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 13  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 25  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 19  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 21  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 20  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 17  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
# 22  pop_edu_collp_pct  Population aged 25+ with a bachelor's degree o...
#
#                         Sub-Borough Area   2000   2005   2006   2007   2008  \
# 38                               Astoria  0.246  0.292  0.305  0.330  0.368
# ...

# %%
#Plot dataframe created above

degree_2017 = list(degree_top10_df['2017'])
clrs2 = ['deeppink' if x == degree_2017[8] or x == degree_2017[5] else 'pink' for x in degree_2017]
sns.barplot(x = '2017',y='Sub-Borough Area',data=degree_top10_df, palette = clrs2)    \
            .set(xlabel = "% of Population with Bachelor's Degree (2017)", ylabel = 'Sub-Borough Area')
# Out:
# [Text(0, 0.5, 'Sub-Borough Area'),
#  Text(0.5, 0, "% of Population with Bachelor's Degree (2017)")]

# %% [markdown]
# ### Additional Info

# %% [markdown]
# ##### Potential Stations near Tech Companies
#
# Flatiron District
# - **14th**
# - **23rd**
# - **28th**
# - 33rd
#
# Financial District
# - **Wall St [2,3]**
# - Broad St [J,Z]
# - **Wall St [4,5]**
# - Broadway/Rector St
# - Broadway/Exchange Al
#
# Dumbo
# - York Street
# - High Street
#
# Midtown
# - **Times Sq-42 St**
# - **34 St - Penn Station**
# - **42 St - Bryant Park Station**
# - **Grand Central - 42 St**
# - **34 St - Herald Square**
